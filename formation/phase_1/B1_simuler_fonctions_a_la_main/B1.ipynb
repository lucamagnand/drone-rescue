# %% [markdown]
# # B1 — Simuler des fonctions à la main
#
# Avant de coder, tu vas **prédire** ce que renvoient des fonctions du jeu,
# en calculant les résultats à la main.
#
# Règle : remplis la valeur attendue **avant** d'exécuter la cellule.

# %%
# Données utiles — ne pas modifier
LETTRES = "ABCDEFGHIJKL"  # 12 lettres : A=0, B=1, ..., L=11

def position_depuis_chaine(chaine):
    lettre = chaine[0]
    num    = int(chaine[1:])
    col    = LETTRES.index(lettre)
    lig    = num - 1
    return (col, lig)

def chaine_depuis_position(col, lig):
    return f"{LETTRES[col]}{lig + 1}"

def distance_chebyshev(col1, lig1, col2, lig2):
    return max(abs(col2 - col1), abs(lig2 - lig1))

# %% [markdown]
# ## Exercice 1 — `position_depuis_chaine`
#
# Avant d'exécuter, calcule à la main le résultat de chaque appel.
# Note tes réponses ici :
#
# | Appel | Résultat attendu (ta réponse) |
# |---|---|
# | `position_depuis_chaine('A1')` | ??? |
# | `position_depuis_chaine('B3')` | ??? |
# | `position_depuis_chaine('L12')` | ??? |
# | `position_depuis_chaine('F6')` | ??? |

# %%
# Vérification — exécute après avoir noté tes réponses ci-dessus
print(position_depuis_chaine('A1'))
print(position_depuis_chaine('B3'))
print(position_depuis_chaine('L12'))
print(position_depuis_chaine('F6'))

# TODO : remplace les ??? par tes valeurs calculées et vérifie
assert position_depuis_chaine('A1')  == ???  # (col, lig) attendu
assert position_depuis_chaine('B3')  == ???
assert position_depuis_chaine('L12') == ???
assert position_depuis_chaine('F6')  == ???

# %% [markdown]
# ## Exercice 2 — `chaine_depuis_position` (sens inverse)
#
# Cette fonction fait l'inverse. Calcule à la main :
#
# | Appel | Résultat attendu |
# |---|---|
# | `chaine_depuis_position(0, 0)` | ??? |
# | `chaine_depuis_position(1, 2)` | ??? |
# | `chaine_depuis_position(11, 11)` | ??? |

# %%
print(chaine_depuis_position(0, 0))
print(chaine_depuis_position(1, 2))
print(chaine_depuis_position(11, 11))

assert chaine_depuis_position(0, 0)    == ???
assert chaine_depuis_position(1, 2)    == ???
assert chaine_depuis_position(11, 11)  == ???

# %% [markdown]
# ## Exercice 3 — `distance_chebyshev`
#
# La distance de Chebyshev = nombre minimum de déplacements en 8 directions.
#
# Calcule à la main, puis vérifie :
#
# | Appel | Résultat attendu |
# |---|---|
# | `distance_chebyshev(0,0, 0,0)` | ??? |
# | `distance_chebyshev(0,0, 3,3)` | ??? |
# | `distance_chebyshev(2,2, 5,4)` | ??? |
# | `distance_chebyshev(0,0, 11,11)` | ??? |

# %%
print(distance_chebyshev(0,0, 0,0))
print(distance_chebyshev(0,0, 3,3))
print(distance_chebyshev(2,2, 5,4))
print(distance_chebyshev(0,0, 11,11))

assert distance_chebyshev(0,0, 0,0)   == ???
assert distance_chebyshev(0,0, 3,3)   == ???
assert distance_chebyshev(2,2, 5,4)   == ???
assert distance_chebyshev(0,0, 11,11) == ???

# %% [markdown]
# ## Exercice 4 — Aller-retour
#
# Si on applique `position_depuis_chaine` puis `chaine_depuis_position` à la même case,
# on doit retrouver la chaîne de départ.
#
# Vérifie ce principe sur 4 cases de ton choix.

# %%
# TODO : choisis 4 cases et vérifie l'aller-retour
for case in [???]:  # remplace ??? par ex. ['A1', 'F6', 'L12', 'C8']
    col, lig = position_depuis_chaine(case)
    retour = chaine_depuis_position(col, lig)
    assert retour == case, f'Aller-retour échoué pour {case} : obtenu {retour}'
    print(f'{case} → ({col},{lig}) → {retour} ✓')

# %% [markdown]
# ## Débrief
#
# Points à retenir :
# - `LETTRES.index('A')` = **0**, pas 1. (0-based)
# - `lig = num - 1` : l'affichage commence à 1, le code à 0.
# - La distance de Chebyshev est toujours un entier ≥ 0.
# - Aller-retour : `chaine_depuis_position(position_depuis_chaine(case)) == case`
#
# Si tous tes `assert` passent, tu es prêt pour B2.
